# %% [markdown]
# # Task-4 Speech Emotion Recognition

# %% [markdown]
# ## The objective of this project is to develop a robust speech emotion recognition system capable of accurately classifying the emotional states conveyed in spoken language. By analyzing the acoustic features of speech signals, the system should be able to categorize emotions such as happiness, sadness, anger, fear, and more.

# %% [markdown]
# ## Author - Prateek Maithil

# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
import librosa
import librosa.display
from IPython.display import Audio
import warnings
warnings.filterwarnings('ignore')

# %%
paths = []
labels = []
for dirname, _, filenames in os.walk("TESS"):
    for filename in filenames:
        paths.append(os.path.join(dirname, filename))
        label = filename.split('_')[-1]
        label = label.split('.')[0]
        labels.append(label.lower())
    if len(paths) == 2800:
        break
print('Dataset is Loaded')
# Out:
# Dataset is Loaded

# %%
len(paths)
# Out:
# 2800

# %%
paths[:5]
# Out:
# ['TESS\\OAF_angry\\OAF_back_angry.wav',
#  'TESS\\OAF_angry\\OAF_bar_angry.wav',
#  'TESS\\OAF_angry\\OAF_base_angry.wav',
#  'TESS\\OAF_angry\\OAF_bath_angry.wav',
#  'TESS\\OAF_angry\\OAF_bean_angry.wav']

# %%
labels[:5]
# Out:
# ['angry', 'angry', 'angry', 'angry', 'angry']

# %%
df = pd.DataFrame()
df['speech'] = paths
df['label'] = labels
df.head()
# Out:
#                               speech  label
# 0  TESS\OAF_angry\OAF_back_angry.wav  angry
# 1   TESS\OAF_angry\OAF_bar_angry.wav  angry
# 2  TESS\OAF_angry\OAF_base_angry.wav  angry
# 3  TESS\OAF_angry\OAF_bath_angry.wav  angry
# 4  TESS\OAF_angry\OAF_bean_angry.wav  angry

# %%
df['label'].value_counts()
# Out:
# label
# angry      400
# disgust    400
# fear       400
# happy      400
# neutral    400
# ps         400
# sad        400
# Name: count, dtype: int64

# %%
sns.countplot(data=df,x='label')
# Out:
# <Axes: xlabel='label', ylabel='count'>

# %%
import numpy as np
import matplotlib.pyplot as plt
import librosa.display
from IPython.display import Audio

# Define emotion and load speech data
emotion = 'fear'
path = np.array(df['speech'][df['label']==emotion])[0]
data, sampling_rate = librosa.load(path)

# Plot waveplot
plt.figure(figsize=(10,4))
plt.title(emotion, size=20)
librosa.display.waveshow(data, sr=sampling_rate)
plt.show()

# Plot spectrogram
plt.figure(figsize=(10,4))
plt.title(emotion + ' Spectrogram', size=20)
D = librosa.amplitude_to_db(np.abs(librosa.stft(data)), ref=np.max)
librosa.display.specshow(D, sr=sampling_rate, x_axis='time', y_axis='log')
plt.colorbar(format='%+2.0f dB')
plt.show()

# Play audio
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import numpy as np
import pandas as pd
import librosa
import librosa.display
import matplotlib.pyplot as plt
from IPython.display import Audio

# Assuming df is your DataFrame containing speech data and labels

# Given emotion
emotion = 'angry'

# Assuming df has 'speech' and 'label' columns
path = np.array(df['speech'][df['label'] == emotion])[1]

# Load audio data and sampling rate
data, sampling_rate = librosa.load(path)

# Waveform plot
plt.figure(figsize=(10, 4))
plt.title(emotion, size=20)
librosa.display.waveshow(data, sr=sampling_rate)
plt.show()

# Spectrogram
plt.figure(figsize=(10, 4))
plt.title('Spectrogram: ' + emotion, size=20)
librosa.display.specshow(librosa.amplitude_to_db(librosa.stft(data), ref=np.max), sr=sampling_rate, x_axis='time', y_axis='log')
plt.colorbar(format='%+2.0f dB')
plt.show()

# Audio playback
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import numpy as np
import matplotlib.pyplot as plt
import librosa
import librosa.display
from IPython.display import Audio

# Define the emotion and path
emotion = 'disgust'
path = np.array(df['speech'][df['label'] == emotion])[0]

# Load the audio data and sampling rate
data, sampling_rate = librosa.load(path)

# Plot the waveplot using matplotlib
plt.figure(figsize=(10, 4))
plt.title(emotion, size=20)
librosa.display.waveshow(data, sr=sampling_rate)
plt.show()

# Plot the spectrogram
plt.figure(figsize=(10, 4))
plt.title('Spectrogram - ' + emotion, size=20)
librosa.display.specshow(librosa.power_to_db(librosa.feature.melspectrogram(y=data, sr=sampling_rate)), y_axis='mel', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.show()

# Play the audio
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import numpy as np
import librosa
import matplotlib.pyplot as plt
from IPython.display import Audio

def waveplot(data, sr, emotion):
    plt.figure(figsize=(10, 4))
    plt.title(emotion, size=20)
    plt.plot(np.arange(len(data)) / sr, data)
    plt.xlabel('Time (s)')
    plt.ylabel('Amplitude')
    plt.show()

# Assuming df and emotion are defined

# Get the path for the first speech sample with the specified emotion
path = np.array(df['speech'][df['label'] == emotion])[0]

# Load the audio data and sampling rate
data, sampling_rate = librosa.load(path)

# Plot the waveplot
waveplot(data, sampling_rate, emotion)

# Display the spectrogram
plt.figure(figsize=(10, 4))
plt.title(f'Spectrogram for {emotion}', size=20)
librosa.display.specshow(librosa.amplitude_to_db(np.abs(librosa.stft(data)), ref=np.max), sr=sampling_rate, x_axis='time', y_axis='log')
plt.colorbar(format='%+2.0f dB')
plt.show()

# Play the audio
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import numpy as np
import matplotlib.pyplot as plt
import librosa
import librosa.display
from IPython.display import Audio

# Assuming df is a DataFrame containing 'speech' and 'label' columns

# Set emotion to 'neutral'
emotion = 'neutral'

# Get the path for the first instance of 'neutral'
path = np.array(df['speech'][df['label'] == emotion])[0]

# Load the audio data and sampling rate
data, sampling_rate = librosa.load(path)

# Plot the waveform
plt.figure(figsize=(10, 4))
plt.title(f'Waveform for {emotion}', size=20)
librosa.display.waveshow(data, sr=sampling_rate)
plt.show()

# Plot the spectrogram
plt.figure(figsize=(10, 4))
plt.title(f'Spectrogram for {emotion}', size=20)
librosa.display.specshow(librosa.amplitude_to_db(np.abs(librosa.stft(data)), ref=np.max), y_axis='log', x_axis='time', sr=sampling_rate)
plt.colorbar(format='%+2.0f dB')
plt.show()

# Display the audio
Audio(path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import numpy as np
import matplotlib.pyplot as plt
import librosa
import librosa.display
from IPython.display import Audio

# Sample data and sampling rate for demonstration purposes
# Replace with your actual data and sampling rate
duration = 10  # Duration of the audio in seconds
sampling_rate = 44100  # Replace with your sampling rate

# Generate sample audio data
t = np.linspace(0, duration, int(sampling_rate * duration), endpoint=False)
data = np.sin(2 * np.pi * 440.0 * t)  # Sample audio (440 Hz sine wave)

# Function to plot waveform
def waveplot(data, sr, emotion):
    plt.figure(figsize=(10, 4))
    plt.title(emotion, size=20)
    librosa.display.waveshow(data, sr=sr)
    plt.show()

# Function to plot spectrogram
def spectrogram(data, sr, emotion):
    plt.figure(figsize=(10, 4))
    plt.title('Spectrogram: ' + emotion, size=20)
    S = librosa.feature.melspectrogram(y=data, sr=sr)
    S_dB = librosa.power_to_db(S, ref=np.max)
    librosa.display.specshow(S_dB, x_axis='time', y_axis='mel', sr=sr, cmap='viridis')
    plt.colorbar(format='%+2.0f dB')
    plt.show()

# Example emotion (replace with your actual emotion)
emotion = 'happy'

# Plot waveform and spectrogram
waveplot(data, sampling_rate, emotion)
spectrogram(data, sampling_rate, emotion)

# Play the audio
Audio(data, rate=sampling_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
def extract_mfcc(filename):
    y, sr = librosa.load(filename, duration=3, offset=0.5)
    mfcc = np.mean(librosa.feature.mfcc(y=y, sr=sr, n_mfcc=40).T, axis=0)
    return mfcc

# %%
extract_mfcc(df['speech'][0])
# Out:
# array([-3.96986206e+02,  7.74405365e+01, -1.95927906e+01, -2.16666889e+01,
#        -2.11275506e+00,  1.00753632e+01, -2.03667068e+01, -6.09244919e+00,
#        -7.21228361e+00, -5.57365894e-01, -1.83255327e+00,  2.02101603e-01,
#         7.27550924e-01,  1.31773770e+00,  2.88633800e+00,  2.85579133e+00,
#        -4.71292162e+00, -4.43651056e+00, -1.62115908e+00, -1.02398405e+01,
#        -7.55126143e+00, -1.79688025e+00, -7.03765202e+00,  9.43658447e+00,
#         8.35585499e+00,  2.17123604e+01,  1.92169895e+01,  2.03489265e+01,
#         1.34133663e+01,  8.33917141e+00,  3.94722581e-01,  5.11131477e+00,
#         9.56873894e+00,  5.45486784e+00,  2.50996375e+00, -1.82390714e+00,
#         4.86896276e+00,  9.31392384e+00,  2.08915019e+00, -1.90649128e+00],
#       dtype=float32)

# %%
X_mfcc = df['speech'].apply(lambda x: extract_mfcc(x))

# %%
X_mfcc
# Out:
# 0       [-396.9862, 77.44054, -19.59279, -21.666689, -...
# 1       [-465.73267, 98.77373, 0.6560089, -32.74544, -...
# 2       [-429.79196, 46.124, 1.5550474, -0.21709539, 2...
# 3       [-403.46118, 76.32369, -12.531774, -22.288858,...
# 4       [-434.05756, 77.4455, 10.865501, 16.092943, 8....
#                               ...
# 2795    [-553.2201, 89.83577, 27.215466, 16.407124, 19...
# 2796    [-589.23676, 96.20408, 36.96118, 15.014448, 28...
# 2797    [-533.41815, 85.43242, 27.791998, 19.307178, 2...
# 2798    [-548.6142, 110.16424, 31.910236, 12.572517, 2...
# 2799    [-549.2962, 102.374565, 32.268833, 26.261616, ...
# Name: speech, Length: 2800, dtype: object

# %%
X = [x for x in X_mfcc]
X = np.array(X)
X.shape
# Out:
# (2800, 40)

# %%
X = np.expand_dims(X, -1)
X.shape
# Out:
# (2800, 40, 1)

# %%
from sklearn.preprocessing import OneHotEncoder
enc = OneHotEncoder()
y = enc.fit_transform(df[['label']])

# %%
y = y.toarray()

# %%
y.shape
# Out:
# (2800, 7)

# %% [markdown]
# pip install tensorflow

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout

model = Sequential([
    LSTM(256, return_sequences=False, input_shape=(40,1)),
    Dropout(0.2),
    Dense(128, activation='relu'),
    Dropout(0.2),
    Dense(64, activation='relu'),
    Dropout(0.2),
    Dense(7, activation='softmax')
])

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 256)               264192
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense (Dense)               (None, 128)               32896
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 7)                 455
#
# =================================================================
# Total params: 305799 (1.17 MB)
# Trainable params: 305799 (1.17 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(X, y, validation_split=0.2, epochs=50, batch_size=64)
# Out:
# Epoch 1/50
# 35/35 [==============================] - 8s 163ms/step - loss: 1.1822 - accuracy: 0.5817 - val_loss: 1.0282 - val_accuracy: 0.6071
# Epoch 2/50
# 35/35 [==============================] - 4s 127ms/step - loss: 0.4718 - accuracy: 0.8411 - val_loss: 0.7234 - val_accuracy: 0.7089
# Epoch 3/50
# 35/35 [==============================] - 5s 147ms/step - loss: 0.2451 - accuracy: 0.9210 - val_loss: 0.1199 - val_accuracy: 0.9607
# Epoch 4/50
# 35/35 [==============================] - 5s 129ms/step - loss: 0.1376 - accuracy: 0.9594 - val_loss: 0.0974 - val_accuracy: 0.9679
# Epoch 5/50
# 35/35 [==============================] - 5s 148ms/step - loss: 0.1351 - accuracy: 0.9598 - val_loss: 0.1082 - val_accuracy: 0.9571
# Epoch 6/50
# 35/35 [==============================] - 5s 144ms/step - loss: 0.1148 - accuracy: 0.9661 - val_loss: 0.1077 - val_accuracy: 0.9607
# Epoch 7/50
# 35/35 [==============================] - 5s 141ms/step - loss: 0.0959 - accuracy: 0.9688 - val_loss: 0.1833 - val_accuracy: 0.9464
# Epoch 8/50
# 35/35 [==============================] - 4s 125ms/step - loss: 0.1239 - accuracy: 0.9616 - val_loss: 0.0790 - val_accuracy: 0.9750
# Epoch 9/50
# 35/35 [==============================] - 6s 164ms/step - loss: 0.0794 - accuracy: 0.9795 - val_loss: 0.0619 - val_accuracy: 0.9768
# Epoch 10/50
# 35/35 [==============================] - 5s 134ms/step - loss: 0.0711 - accuracy: 0.9763 - val_loss: 0.1636 - val_accuracy: 0.9393
# Epoch 11/50
# 35/35 [==============================] - 5s 147ms/step - loss: 0.0770 - accuracy: 0.9746 - val_loss: 0.1157 - val_accuracy: 0.9589
# Epoch 12/50
# 35/35 [==============================] - 6s 172ms/step - loss: 0.1106 - accuracy: 0.9652 - val_loss: 0.0837 - val_accuracy: 0.9696
# Epoch 13/50
# 35/35 [==============================] - 5s 131ms/step - loss: 0.0512 - accuracy: 0.9862 - val_loss: 0.1231 - val_accuracy: 0.9607
# Epoch 14/50
# 35/35 [==============================] - 5s 149ms/step - loss: 0.0322 - accuracy: 0.9902 - val_loss: 0.0319 - val_accuracy: 0.9857
# Epoch 15/50
# 35/35 [==============================] - 4s 121ms/step - loss: 0.0369 - accuracy: 0.9893 - val_loss: 0.0527 - val_accuracy: 0.9768
# Epoch 16/50
# 35/35 [==============================] - 4s 123ms/step - loss: 0.0268 - accuracy: 0.9920 - val_loss: 0.0113 - val_accuracy: 0.9929
# Epoch 17/50
# 35/35 [==============================] - 4s 112ms/step - loss: 0.0477 - accuracy: 0.9866 - val_loss: 0.0602 - val_accuracy: 0.9768
# Epoch 18/50
# 35/35 [==============================] - 4s 120ms/step - loss: 0.0603 - accuracy: 0.9808 - val_loss: 0.0255 - val_accuracy: 0.9929
# Epoch 19/50
# 35/35 [==============================] - 5s 130ms/step - loss: 0.0253 - accuracy: 0.9929 - val_loss: 0.0164 - val_accuracy: 0.9946
# Epoch 20/50
# 35/35 [==============================] - 5s 138ms/step - loss: 0.0141 - accuracy: 0.9951 - val_loss: 0.0115 - val_accuracy: 0.9964
# Epoch 21/50
# 35/35 [==============================] - 6s 161ms/step - loss: 0.0229 - accuracy: 0.9924 - val_loss: 0.0131 - val_accuracy: 0.9946
# Epoch 22/50
# 35/35 [==============================] - 5s 145ms/step - loss: 0.0312 - accuracy: 0.9920 - val_loss: 0.0361 - val_accuracy: 0.9893
# Epoch 23/50
# 35/35 [==============================] - 6s 171ms/step - loss: 0.0336 - accuracy: 0.9888 - val_loss: 0.0277 - val_accuracy: 0.9911
# Epoch 24/50
# 35/35 [==============================] - 5s 134ms/step - loss: 0.0164 - accuracy: 0.9942 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 25/50
# 35/35 [==============================] - 4s 127ms/step - loss: 0.0087 - accuracy: 0.9973 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 26/50
# 35/35 [==============================] - 4s 114ms/step - loss: 0.0031 - accuracy: 0.9996 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 27/50
# 35/35 [==============================] - 5s 157ms/step - loss: 0.0053 - accuracy: 0.9987 - val_loss: 3.3090e-04 - val_accuracy: 1.0000
# Epoch 28/50
# 35/35 [==============================] - 6s 161ms/step - loss: 0.0362 - accuracy: 0.9906 - val_loss: 0.1642 - val_accuracy: 0.9661
# Epoch 29/50
# 35/35 [==============================] - 5s 140ms/step - loss: 0.0452 - accuracy: 0.9911 - val_loss: 0.0149 - val_accuracy: 0.9946
# Epoch 30/50
# 35/35 [==============================] - 6s 165ms/step - loss: 0.0265 - accuracy: 0.9924 - val_loss: 0.0038 - val_accuracy: 1.0000
# Epoch 31/50
# 35/35 [==============================] - 5s 139ms/step - loss: 0.0439 - accuracy: 0.9897 - val_loss: 0.0473 - val_accuracy: 0.9911
# Epoch 32/50
# 35/35 [==============================] - 5s 151ms/step - loss: 0.0168 - accuracy: 0.9946 - val_loss: 0.0083 - val_accuracy: 0.9964
# Epoch 33/50
# 35/35 [==============================] - 5s 133ms/step - loss: 0.0050 - accuracy: 0.9987 - val_loss: 0.0040 - val_accuracy: 0.9982
# Epoch 34/50
# 35/35 [==============================] - 5s 138ms/step - loss: 0.0036 - accuracy: 0.9996 - val_loss: 0.0016 - val_accuracy: 0.9982
# Epoch 35/50
# 35/35 [==============================] - 6s 163ms/step - loss: 0.0031 - accuracy: 0.9991 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 36/50
# 35/35 [==============================] - 5s 154ms/step - loss: 0.0272 - accuracy: 0.9933 - val_loss: 0.0056 - val_accuracy: 0.9964
# Epoch 37/50
# 35/35 [==============================] - 6s 159ms/step - loss: 0.0407 - accuracy: 0.9884 - val_loss: 0.0199 - val_accuracy: 0.9929
# Epoch 38/50
# 35/35 [==============================] - 6s 169ms/step - loss: 0.0287 - accuracy: 0.9897 - val_loss: 0.0526 - val_accuracy: 0.9857
# Epoch 39/50
# 35/35 [==============================] - 6s 160ms/step - loss: 0.0093 - accuracy: 0.9982 - val_loss: 6.1255e-04 - val_accuracy: 1.0000
# Epoch 40/50
# 35/35 [==============================] - 5s 146ms/step - loss: 0.0037 - accuracy: 0.9991 - val_loss: 2.4809e-04 - val_accuracy: 1.0000
# Epoch 41/50
# 35/35 [==============================] - 5s 130ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 2.1402e-04 - val_accuracy: 1.0000
# Epoch 42/50
# 35/35 [==============================] - 4s 124ms/step - loss: 5.0848e-04 - accuracy: 1.0000 - val_loss: 1.4547e-04 - val_accuracy: 1.0000
# Epoch 43/50
# 35/35 [==============================] - 5s 140ms/step - loss: 3.9935e-04 - accuracy: 1.0000 - val_loss: 7.3698e-05 - val_accuracy: 1.0000
# Epoch 44/50
# 35/35 [==============================] - 5s 150ms/step - loss: 3.4240e-04 - accuracy: 1.0000 - val_loss: 5.0451e-05 - val_accuracy: 1.0000
# Epoch 45/50
# 35/35 [==============================] - 4s 124ms/step - loss: 3.0230e-04 - accuracy: 1.0000 - val_loss: 3.1838e-05 - val_accuracy: 1.0000
# Epoch 46/50
# 35/35 [==============================] - 4s 127ms/step - loss: 2.0623e-04 - accuracy: 1.0000 - val_loss: 3.3072e-05 - val_accuracy: 1.0000
# Epoch 47/50
# 35/35 [==============================] - 4s 128ms/step - loss: 2.0141e-04 - accuracy: 1.0000 - val_loss: 3.1724e-05 - val_accuracy: 1.0000
# Epoch 48/50
# 35/35 [==============================] - 5s 140ms/step - loss: 2.0786e-04 - accuracy: 1.0000 - val_loss: 2.3807e-05 - val_accuracy: 1.0000
# Epoch 49/50
# 35/35 [==============================] - 5s 134ms/step - loss: 1.8586e-04 - accuracy: 1.0000 - val_loss: 1.7409e-05 - val_accuracy: 1.0000
# Epoch 50/50
# 35/35 [==============================] - 5s 132ms/step - loss: 1.3723e-04 - accuracy: 1.0000 - val_loss: 1.6021e-05 - val_accuracy: 1.0000

# %%
epochs = list(range(50))
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, label='train accuracy')
plt.plot(epochs, val_acc, label='val accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']

plt.plot(epochs, loss, label='train loss')
plt.plot(epochs, val_loss, label='val loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend()
plt.show()
